# %%
import gdown

# %%
url="https://drive.google.com/file/d/1g9Box8IlTBnDiIYKWYp3kWXISOFnfyjd/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]

# %%
prefix='https://drive.google.com/uc?/export/=download&id='
gdown.download(prefix+file_id,"kidney_image_ct_scan.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export/=download&id=1g9Box8IlTBnDiIYKWYp3kWXISOFnfyjd
# From (redirected): https://drive.google.com/uc?%2Fexport%2F=download&id=1g9Box8IlTBnDiIYKWYp3kWXISOFnfyjd&confirm=t&uuid=8f741632-f454-44e0-a14f-86f27506f9cf
# To: e:\kindey_disease_classification\research\kidney_image_ct_scan.zip
# 100%|██████████| 940M/940M [04:20<00:00, 3.61MB/s]
# 'kidney_image_ct_scan.zip'
